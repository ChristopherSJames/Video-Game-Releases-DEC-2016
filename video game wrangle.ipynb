# %% [markdown]
# # Video Game Wrangle
#
# In this section, I will be wrangling and cleaning data from the csv file 'Video_Games_Sales_as_at_22_Dec_2016.csv'.

# %% [markdown]
# ## Gather

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
# read csv file into dataframe
df_original = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')

# %%
# copy df before wrangling begins.
df = df_original.copy()

# %% [markdown]
# ## Assess

# %% [markdown]
# ### Quality

# %% [markdown]
# * (1) There are 2 rows that do not have names, one of which is missing many other attributes.
# * (2) There are 4 rows containing games that released after 2016.
# * (3) The column **User_Score** is of the wrong datatype(object) and contains 2425 instances of the string 'tbd'.
# * (4) There are 2 duplicate rows in this dataframe.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
# Name               16717 non-null object
# Platform           16719 non-null object
# Year_of_Release    16450 non-null float64
# Genre              16717 non-null object
# Publisher          16665 non-null object
# NA_Sales           16719 non-null float64
# EU_Sales           16719 non-null float64
# JP_Sales           16719 non-null float64
# Other_Sales        16719 non-null float64
# Global_Sales       16719 non-null float64
# Critic_Score       8137 non-null float64
# Critic_Count       8137 non-null float64
# User_Score         10015 non-null object
# User_Count         7590 non-null float64
# Developer          10096 non-null object
# Rating             9950 non-null object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %% [markdown]
# #### Assessment 1

# %%
# Create a list of index values for rows that do not contain names.
no_name = list(df.query('Name != Name').index.values.tolist())

# %%
df.loc[no_name]
# Out:
#       Name Platform  Year_of_Release Genre              Publisher  NA_Sales  \
# 659    NaN      GEN           1993.0   NaN  Acclaim Entertainment      1.78
# 14246  NaN      GEN           1993.0   NaN  Acclaim Entertainment      0.00
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 659        0.53      0.00         0.08          2.39           NaN
# 14246      0.00      0.03         0.00          0.03           NaN
#
#        Critic_Count User_Score  User_Count Developer Rating
# 659             NaN        NaN         NaN       NaN    NaN
# 14246           NaN        NaN         NaN       NaN    NaN

# %% [markdown]
# #### Assessment 2

# %%
# Create a list of index values for rows that contain release dates that are later than 2016
false_release = list(df.query('Year_of_Release > 2016').index.values.tolist())

# %%
df.loc[false_release]
# Out:
#                                                    Name Platform  \
# 5936                             Imagine: Makeup Artist       DS
# 14086  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 16222  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
# 16385                  Brothers Conflict: Precious Baby      PSV
#
#        Year_of_Release         Genre     Publisher  NA_Sales  EU_Sales  \
# 5936            2020.0    Simulation       Ubisoft      0.27       0.0
# 14086           2017.0  Role-Playing          Sega      0.00       0.0
# 16222           2017.0  Role-Playing          Sega      0.00       0.0
# 16385           2017.0        Action  Idea Factory      0.00       0.0
#
#        JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 5936       0.00         0.02          0.29           NaN           NaN
# 14086      0.04         0.00          0.04           NaN           NaN
# 16222      0.01         0.00          0.01           NaN           NaN
# 16385      0.01         0.00          0.01           NaN           NaN
#
#       User_Score  User_Count Developer Rating
# 5936         tbd         NaN   Ubisoft      E
# 14086        NaN         NaN       NaN    NaN
# 16222        NaN         NaN       NaN    NaN
# 16385        NaN         NaN       NaN    NaN

# %% [markdown]
# #### Assessment 3

# %%
# Create a list of index values for rows that contain user scores whose values are 'tbd'.
false_uscore = list(df.query('User_Score == "tbd"').index.values.tolist())
df.loc[false_uscore]
# Out:
#                                                 Name Platform  \
# 119                                    Zumba Fitness      Wii
# 301                   Namco Museum: 50th Anniversary      PS2
# 520                                  Zumba Fitness 2      Wii
# 645                                     uDraw Studio      Wii
# 1292       1.04      0.37      0.00         0.06          1.47           NaN
# 1298       1.02      0.38      0.00         0.06          1.46           NaN
# 1300       0.72      0.56      0.00         0.19          1.46          76.0
# 1309       0.46      0.82      0.00         0.17          1.46          54.0
# 1341       1.12      0.19      0.00         0.11          1.43           NaN
# 1367       0.78      0.51      0.00         0.12          1.41           NaN
# 1423       0.23      0.04      0.00         1.09          1.36          64.0
# 1487       0.71      0.48      0.00         0.13          1.32           NaN
# 1541       0.55      0.59      0.00         0.14          1.28           NaN
# 1560       0.75      0.39      0.00         0.12          1.27          65.0
# 1700       0.77      0.31      0.00         0.11          1.19           NaN
# ...         ...       ...       ...          ...           ...           ...
# 16474      0.01      0.00      0.00         0.00          0.01          42.0
# 16482      0.01      0.00      0.00         0.00          0.01           NaN
# 16489      0.00      0.01      0.00         0.00          0.01           NaN
# 16497      0.01      0.00      0.00         0.00          0.01          35.0
# 16498      0.01      0.00      0.00         0.00          0.01           NaN
# 16511      0.00      0.00      0.01         0.00          0.01          53.0
# 16524      0.00      0.01      0.00         0.00          0.01           NaN
# 16525      0.01      0.00      0.00         0.00          0.01           NaN
# 16538      0.01      0.00      0.00         0.00          0.01           NaN
# 16566      0.01      0.00      0.00         0.00          0.01           NaN
# 16572      0.00      0.01      0.00         0.00          0.01           NaN
# 16578      0.01      0.00      0.00         0.00          0.01           NaN
# 16581      0.01      0.00      0.00         0.00          0.01          40.0
# 16597      0.00      0.01      0.00         0.00          0.01           NaN
# 16603      0.00      0.01      0.00         0.00          0.01           NaN
# 16619      0.01      0.00      0.00         0.00          0.01           NaN
# 16630      0.01      0.00      0.00         0.00          0.01           NaN
# 16637      0.01      0.00      0.00         0.00          0.01           NaN
# 16642      0.00      0.01      0.00         0.00          0.01           NaN
# 16651      0.00      0.00      0.01         0.00          0.01           NaN
# 16654      0.00      0.01      0.00         0.00          0.01           NaN
# 16659      0.00      0.01      0.00         0.00          0.01           NaN
# 16673      0.01      0.00      0.00         0.00          0.01          72.0
# 16676      0.01      0.00      0.00         0.00          0.01           NaN
# 16692      0.01      0.00      0.00         0.00          0.01           NaN
# 16699      0.01      0.00      0.00         0.00          0.01          67.0
# 16701      0.01      0.00      0.00         0.00          0.01          53.0
# 16702      0.01      0.00      0.00         0.00          0.01          48.0
# 16708      0.01      0.00      0.00         0.00          0.01           NaN
# 16710      0.01      0.00      0.00         0.00          0.01           NaN
#
#        Critic_Count User_Score  User_Count  \
# 119             NaN        tbd         NaN
# 301            21.0        tbd         NaN
# 520             NaN        tbd         NaN
# 645             9.0        tbd         NaN
# 657             4.0        tbd         NaN
# 718             NaN        tbd         NaN
# 726             NaN        tbd         NaN
# 821            13.0        tbd         NaN
# 881             NaN        tbd         NaN
# 1047           10.0        tbd         NaN
# 1048            NaN        tbd         NaN
# 1069           11.0        tbd         NaN
# 1070            4.0        tbd         NaN
# 1089            NaN        tbd         NaN
# 1151            5.0        tbd         NaN
# 1199            9.0        tbd         NaN
# 1210            NaN        tbd         NaN
# 1284            NaN        tbd         NaN
# 1291            NaN        tbd         NaN
# 1292            NaN        tbd         NaN
# 1298            NaN        tbd         NaN
# 1300           22.0        tbd         NaN
# 1309           15.0        tbd         NaN
# 1341            NaN        tbd         NaN
# 1367            NaN        tbd         NaN
# 1423           11.0        tbd         NaN
# 1487            NaN        tbd         NaN
# 1541            NaN        tbd         NaN
# 1560           28.0        tbd         NaN
# 1700            NaN        tbd         NaN
# ...             ...        ...         ...
# 16474           6.0        tbd         NaN
# 16482           NaN        tbd         NaN
# 16489           NaN        tbd         NaN
# 16497           5.0        tbd         NaN
# 16498           NaN        tbd         NaN
# 16511          15.0        tbd         NaN
# 16524           NaN        tbd         NaN
# 16525           NaN        tbd         NaN
# 16538           NaN        tbd         NaN
# 16566           NaN        tbd         NaN
# 16572           NaN        tbd         NaN
# 16578           NaN        tbd         NaN
# 16581           8.0        tbd         NaN
# 16597           NaN        tbd         NaN
# 16603           NaN        tbd         NaN
# 16619           NaN        tbd         NaN
# 16630           NaN        tbd         NaN
# 16637           NaN        tbd         NaN
# 16642           NaN        tbd         NaN
# 16651           NaN        tbd         NaN
# 16654           NaN        tbd         NaN
# 16659           NaN        tbd         NaN
# 16673          13.0        tbd         NaN
# 16676           NaN        tbd         NaN
# 16692           NaN        tbd         NaN
# 16699           9.0        tbd         NaN
# 16701           4.0        tbd         NaN
# 16702          10.0        tbd         NaN
# 16708           NaN        tbd         NaN
# 16710           NaN        tbd         NaN
#
#                                   Developer Rating
# 119                Pipeworks Software, Inc.      E
# 301                         Digital Eclipse   E10+
# 520                  Majesco Games, Majesco      T
# 645                                     THQ      E
# 657    Konami Computer Entertainment Hawaii      E
# 718                                 Ubisoft      E
# 726                                  Konami   E10+
# 821                                  Helixe      E
# 881                             Jellyvision      E
# 1047                              3d6 Games      E
# 1048                          Magic Pockets      E
# 1069                    Jupiter Corporation      E
# 1070                       Farsight Studios      E
# 1089           Artificial Mind and Movement      E
# 1151                                    THQ      E
# 1199                                   TOSE      E
# 1210                             Mind Candy      E
# 1284                               Zoe Mode      E
# 1291                                Ubisoft      E
# 1292                                    Art      E
# 1298                             WayForward      E
# 1300                                 Midway      T
# 1309                                 Helixe      E
# 1341               1st Playable Productions      E
# 1367                        Barnstorm Games      E
# 1423                     SCEE London Studio      T
# 1487                          Magic Pockets      E
# 1541          Lexis Numerique, Virtual Toys      E
# 1560                       Griptonite Games      E
# 1700                               Zoe Mode      E
# ...                                     ...    ...
# 16474                             Runecraft      E
# 16482                         Magic Pockets   E10+
# 16489                       Electronic Arts      T
# 16497                       Happy Happening   E10+
# 16498                    Mentor Interactive      E
# 16511                          SNK Playmore      T
# 16524                             Haemimont      T
# 16525                                Konami      E
# 16538                            Alpha Unit      E
# 16566                               Mastiff      T
# 16572                     Mac Play, MacPlay      E
# 16578                       UFO Interactive      E
# 16581                     Taito Corporation      T
# 16597                          Little Orbit      E
# 16603                 Black Lantern Studios      E
# 16619                       UFO Interactive      E
# 16630                               Neopica      T
# 16637                       Milestone S.r.l   E10+
# 16642                               Cyanide      E
# 16651                                Konami      M
# 16654                          Oberon Media      T
# 16659                               49Games    NaN
# 16673                             Banpresto      T
# 16676                    Kojima Productions      M
# 16692                               Mastiff      T
# 16699                    Planet Interactive      E
# 16701                     Taito Corporation      E
# 16702                    Interchannel-Holon      E
# 16708                        Big John Games      E
# 16710                                 Atari      T
#
# [2425 rows x 16 columns]

# %% [markdown]
# #### Assessment 4

# %%
#Create a list of index values for rows that are duplicates based on the columns 'Name', 'Platform', and 'Year_of_Release'.
duplicate = list(df[df.duplicated(subset = ['Name', 'Platform', 'Year_of_Release'])].index.values.tolist())
df.loc[duplicate]
# Out:
#                 Name Platform  Year_of_Release   Genre              Publisher  \
# 14246            NaN      GEN           1993.0     NaN  Acclaim Entertainment
# 16233  Madden NFL 13      PS3           2012.0  Sports        Electronic Arts
#
#        NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 14246       0.0      0.00      0.03          0.0          0.03           NaN
# 16233       0.0      0.01      0.00          0.0          0.01          83.0
#
#        Critic_Count User_Score  User_Count   Developer Rating
# 14246           NaN        NaN         NaN         NaN    NaN
# 16233          22.0        5.5       101.0  EA Tiburon      E

# %% [markdown]
# ### Tidiness
#
# There are no tidiness issues with this dataframe.

# %% [markdown]
# ## Clean

# %% [markdown]
# ### Quality

# %% [markdown]
# #### Assessment 1 - Define

# %% [markdown]
# Since both rows are missing so much information, including critical information, and there is no way to tell if these entries
# are mistakes or not, I will be removing both rows.

# %% [markdown]
# #### Assessment 1 - Code

# %%
# drop rows that are part of the previously made 'duplicate' index.
df.drop(no_name, inplace = True)

# %% [markdown]
# #### Assessment 1 - Test

# %%
df.query('Name != Name')
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year_of_Release, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales, Critic_Score, Critic_Count, User_Score, User_Count, Developer, Rating]
# Index: []

# %% [markdown]
# #### Assessment 2 - Define

# %% [markdown]
# I will Use df.drop() to remove the rows of the games that came out after 2016.

# %% [markdown]
# #### Assessment 2 - Code

# %%
# Remove the rows of the games that came out after 2016.
df.drop(false_release, inplace = True)

# %% [markdown]
# #### Assessment 2 - Test

# %%
df.query('Year_of_Release > 2016')
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year_of_Release, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales, Critic_Score, Critic_Count, User_Score, User_Count, Developer, Rating]
# Index: []

# %% [markdown]
# #### Assessment 3 - Define

# %% [markdown]
# I will convert the column **User_Score** to the datatype 'float'.

# %% [markdown]
# #### Assessment 3 - Code

# %%
# Convert the column 'User_Score' to float via the 'to_numeric' function.
df['User_Score'] = df['User_Score'].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# #### Assessment 3 - Test

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16718
# Data columns (total 16 columns):
# Name               16713 non-null object
# Platform           16713 non-null object
# Year_of_Release    16444 non-null float64
# Genre              16713 non-null object
# Publisher          16659 non-null object
# NA_Sales           16713 non-null float64
# EU_Sales           16713 non-null float64
# JP_Sales           16713 non-null float64
# Other_Sales        16713 non-null float64
# Global_Sales       16713 non-null float64
# Critic_Score       8137 non-null float64
# Critic_Count       8137 non-null float64
# User_Score         7590 non-null float64
# User_Count         7590 non-null float64
# Developer          10095 non-null object
# Rating             9949 non-null object
# dtypes: float64(10), object(6)
# memory usage: 2.2+ MB

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# 0          51.0         8.0       322.0  Nintendo      E
# 1           NaN         NaN         NaN       NaN    NaN
# 2          73.0         8.3       709.0  Nintendo      E
# 3          73.0         8.0       192.0  Nintendo      E
# 4           NaN         NaN         NaN       NaN    NaN

# %% [markdown]
# #### Assessment 4 - Define

# %% [markdown]
# One of these duplicates was taken care of after cleaning the first assessment. The other one will be removed.

# %% [markdown]
# #### Assessment 4 - Code

# %%
# drop rows that are part of the previously made 'duplicate' index list, after removing the index of the row that
# was already dropped.
duplicate = [16233]
df.drop(duplicate, inplace = True)

# %% [markdown]
# #### Assessment 4 - Test

# %%
df.duplicated(subset = ['Name', 'Platform', 'Year_of_Release']).sum()
# Out:
# 0

# %%
# Storing final dataframe in a csv file called 'Video_Games_Sales_as_at_22_Dec_2016_master.csv'
df.to_csv('Video_Games_Sales_as_at_22_Dec_2016_master.csv', index = False)
